# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %%
# %matplotlib inline
from DLBio.pytorch_helpers import get_device, get_num_params
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from SiameseNetworkDataset import SiameseNetworkDataset
from SiameseNetwork_Mobilenet import MyMobileNetV2
from SiameseNetwork import SiameseNetwork
from torchvision.models.mobilenet import mobilenet_v2

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
# Set Up All Configurations here
class Config():
    training_dir = "./data/ears/training/"
    testing_dir = "./data/ears/testing/"
    train_batch_size = 64
    train_number_epochs = 50

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]]

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# Epoch number 0
#  Current loss 1.7781251668930054
#
# Epoch number 0
#  Current loss 4.757500648498535
#
# Epoch number 1
#  Current loss 2.0619940757751465
#
# Epoch number 1
#  Current loss 0.8769974112510681
#
# Epoch number 2
#  Current loss 1.2832883596420288
#
# Epoch number 2
#  Current loss 1.8956652879714966
#
# Epoch number 3
#  Current loss 0.8023319840431213
#
# Epoch number 3
#  Current loss 0.7043560743331909
#
# Epoch number 4
#  Current loss 1.2645630836486816
#
# Epoch number 4
#  Current loss 0.6450101733207703
#
# Epoch number 5
#  Current loss 0.7884335517883301
#
# Epoch number 5
#  Current loss 4.9074320793151855
#
# Epoch number 6
#  Current loss 0.498470664024353
#
# Epoch number 6
#  Current loss 0.4883865714073181
#
# Epoch number 7
#  Current loss 0.4415859580039978
#
# Epoch number 7
#  Current loss 0.36889931559562683
#
# Epoch number 8
#  Current loss 0.4355648159980774
#
# Epoch number 8
#  Current loss 0.5388395190238953
#
# Epoch number 9
#  Current loss 0.5532888174057007
#
# Epoch number 9
#  Current loss 0.4608304798603058
#
# Epoch number 10
#  Current loss 0.48123419284820557
#
# Epoch number 10
#  Current loss 0.43308737874031067
#
# Epoch number 11
#  Current loss 0.418856143951416
#
# Epoch number 11
#  Current loss 0.35622990131378174
#
# Epoch number 12
#  Current loss 0.3879657983779907
#
# Epoch number 12
#  Current loss 0.24956031143665314
#
# Epoch number 13
#  Current loss 0.3461778461933136
#
# Epoch number 13
#  Current loss 0.20496121048927307
#
# Epoch number 14
#  Current loss 0.2759922742843628
#
# Epoch number 14
#  Current loss 0.34854769706726074
#
# Epoch number 15
#  Current loss 0.392032265663147
#
# Epoch number 15
#  Current loss 0.19204150140285492
#
# Epoch number 16
#  Current loss 0.336397647857666
#
# Epoch number 16
#  Current loss 0.1853935569524765
#
# Epoch number 17
#  Current loss 0.1722654402256012
#
# Epoch number 17
#  Current loss 0.20443427562713623
#
# Epoch number 18
#  Current loss 0.2574509382247925
#
# Epoch number 18
#  Current loss 0.15751439332962036
#
# Epoch number 19
#  Current loss 0.14807666838169098
#
# Epoch number 19
#  Current loss 0.17504729330539703
#
# Epoch number 20
#  Current loss 0.17080456018447876
#
# Epoch number 20
#  Current loss 0.15092268586158752
#
# Epoch number 21
#  Current loss 0.14725825190544128
#
# Epoch number 21
#  Current loss 0.19787873327732086
#
# Epoch number 22
#  Current loss 0.11546333134174347
#
# Epoch number 22
#  Current loss 0.10389896482229233
#
# Epoch number 23
#  Current loss 0.17701198160648346
#
# Epoch number 23
#  Current loss 0.2702971398830414
#
# Epoch number 24
#  Current loss 0.19164761900901794
#
# Epoch number 24
#  Current loss 0.0900968611240387
#
# Epoch number 25
#  Current loss 0.17957380414009094
#
# Epoch number 25
#  Current loss 0.13714514672756195
#
# Epoch number 26
#  Current loss 0.18746566772460938
#
# Epoch number 26
#  Current loss 0.11644821614027023
#
# Epoch number 27
#  Current loss 0.1268526166677475
#
# Epoch number 27
#  Current loss 0.14141184091567993
#
# Epoch number 28
#  Current loss 0.0876852422952652
#
# Epoch number 28
#  Current loss 0.10330366343259811
#
# Epoch number 29
#  Current loss 0.11285370588302612
#
# Epoch number 29
#  Current loss 0.10663286596536636
#
# Epoch number 30
#  Current loss 0.08172670006752014
#
# Epoch number 30
#  Current loss 0.11715609580278397
#
# Epoch number 31
#  Current loss 0.11248668283224106
#
# Epoch number 31
#  Current loss 0.11411814391613007
#
# Epoch number 32
#  Current loss 0.08312952518463135
#
# Epoch number 32
#  Current loss 0.10858767479658127
#
# Epoch number 33
#  Current loss 0.12547987699508667
#
# Epoch number 33
#  Current loss 0.059823740273714066
#
# Epoch number 34
#  Current loss 0.13468237221240997
#
# Epoch number 34
#  Current loss 0.0691869929432869
#
# Epoch number 35
#  Current loss 0.10316898673772812
#
# Epoch number 35
#  Current loss 0.09685469418764114
#
# Epoch number 36
#  Current loss 0.08548267185688019
#
# Epoch number 36
#  Current loss 0.06121765449643135
#
# Epoch number 37
#  Current loss 0.06931957602500916
#
# Epoch number 37
#  Current loss 0.13562443852424622
#
# Epoch number 38
#  Current loss 0.08820757269859314
#
# Epoch number 38
#  Current loss 0.06216423213481903
#
# Epoch number 39
#  Current loss 0.11759080737829208
#
# Epoch number 39
#  Current loss 0.06266970932483673
#
# Epoch number 40
#  Current loss 0.08138345927000046
#
# Epoch number 40
#  Current loss 0.06127161160111427
#
# Epoch number 41
#  Current loss 0.07662263512611389
#
# Epoch number 41
#  Current loss 0.051574986428022385
#
# Epoch number 42
#  Current loss 0.0653875321149826
#
# Epoch number 42
#  Current loss 0.07424814999103546
#
# Epoch number 43
#  Current loss 0.07299928367137909
#
# Epoch number 43
#  Current loss 0.05549878999590874
#
# Epoch number 44
#  Current loss 0.07715081423521042
#
# Epoch number 44
#  Current loss 0.06470552831888199
#
# Epoch number 45
#  Current loss 0.06601662933826447
#
# Epoch number 45
#  Current loss 0.1016664057970047
#
# Epoch number 46
#  Current loss 0.07805250585079193
#
# Epoch number 46
#  Current loss 0.06378170102834702
#
# Epoch number 47
#  Current loss 0.053504861891269684
#
# Epoch number 47
#  Current loss 0.09579607844352722
#
# Epoch number 48
#  Current loss 0.1037011444568634
#
# Epoch number 48
#  Current loss 0.11830020695924759
#
# Epoch number 49
#  Current loss 0.054493632167577744
#
# Epoch number 49
#  Current loss 0.1239008978009224

# %%
#torch.save(net,'/nfshome/lentzsch/Documents/Bachelorarbeit/Bachelorthesis/models/model.pt' )
#torch.save(net.state_dict(), '/nfshome/lentzsch/Documents/Bachelorarbeit/Bachelorthesis/models/model_dict.pt')

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
